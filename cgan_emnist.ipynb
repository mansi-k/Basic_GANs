# %% [markdown]
# # Training Conditional GAN on EMNIST

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/smai_project2/
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/smai_project2
# /content/drive/MyDrive/smai_project2

# %%
# !python cgan_emnist.py --save_ckpt 'emnist' #--load_ckpt 'mnist'
# Out:
# Namespace(b1=0.5, b2=0.999, batch_size=64, channels=1, img_size=32, latent_dim=100, load_ckpt=None, lr=0.0002, n_classes=26, n_cpu=8, n_epochs=200, sample_interval=400, save_ckpt='emnist')
# [Epoch 0/200] [Batch 1949/1950] [D loss: 0.083861] [G loss: 0.696954]
# [Epoch 1/200] [Batch 1949/1950] [D loss: 0.109717] [G loss: 0.530293]
# [Epoch 2/200] [Batch 1949/1950] [D loss: 0.142094] [G loss: 0.719187]
# [Epoch 3/200] [Batch 1949/1950] [D loss: 0.103335] [G loss: 0.679044]
# [Epoch 4/200] [Batch 1949/1950] [D loss: 0.127034] [G loss: 0.596544]
# [Epoch 5/200] [Batch 1949/1950] [D loss: 0.164517] [G loss: 0.613159]
# [Epoch 6/200] [Batch 1949/1950] [D loss: 0.186583] [G loss: 0.546402]
# [Epoch 7/200] [Batch 1949/1950] [D loss: 0.173220] [G loss: 0.486516]
# [Epoch 8/200] [Batch 1949/1950] [D loss: 0.150700] [G loss: 0.651034]
# [Epoch 9/200] [Batch 1949/1950] [D loss: 0.164318] [G loss: 0.482957]
# [Epoch 10/200] [Batch 1949/1950] [D loss: 0.186571] [G loss: 0.444540]
# ...
