# %% [markdown]
# # Training GAN on MNIST

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/smai_project/
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/smai_project
# /content/drive/MyDrive/smai_project

# %%
# !python gan_mnist.py --save_ckpt 'mnist' --load_ckpt 'mnist'
# Out:
# Namespace(b1=0.5, b2=0.999, batch_size=64, channels=1, img_size=28, latent_dim=100, load_ckpt='mnist', lr=0.0002, n_cpu=8, n_epochs=400, sample_interval=400, save_ckpt='mnist')
# [Epoch 200/400] [Batch 937/938] [D loss: 0.195760] [G loss: 3.035346]
# [Epoch 201/400] [Batch 937/938] [D loss: 0.170264] [G loss: 3.018728]
# [Epoch 202/400] [Batch 937/938] [D loss: 0.146074] [G loss: 3.850143]
# [Epoch 203/400] [Batch 937/938] [D loss: 0.108678] [G loss: 2.455504]
# [Epoch 204/400] [Batch 937/938] [D loss: 0.282043] [G loss: 3.719071]
# [Epoch 205/400] [Batch 937/938] [D loss: 0.216387] [G loss: 3.307374]
# [Epoch 206/400] [Batch 937/938] [D loss: 0.255962] [G loss: 3.215297]
# [Epoch 207/400] [Batch 937/938] [D loss: 0.234721] [G loss: 3.225156]
# [Epoch 208/400] [Batch 937/938] [D loss: 0.162006] [G loss: 3.169020]
# [Epoch 209/400] [Batch 937/938] [D loss: 0.351100] [G loss: 3.085097]
# [Epoch 210/400] [Batch 937/938] [D loss: 0.259296] [G loss: 4.203687]
# ...
