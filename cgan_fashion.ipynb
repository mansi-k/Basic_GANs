# %% [markdown]
# # Training Conditional GAN on FashionMNIST

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/smaiproject_3
/
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1cK4xKubP5lL9CFyNaFzbqhtdZHtV9nBG/smaiproject_3
# /content/drive/.shortcut-targets-by-id/1cK4xKubP5lL9CFyNaFzbqhtdZHtV9nBG/smaiproject_3

# %%
# !python cgan_fashion.py --save_ckpt 'fashionmnist' #--load_ckpt 'fashionmnist'
# Out:
# Namespace(b1=0.5, b2=0.999, batch_size=64, channels=1, img_size=32, latent_dim=100, load_ckpt=None, lr=0.0002, n_classes=10, n_cpu=8, n_epochs=200, sample_interval=400, save_ckpt='fashionmnist')
# [Epoch 0/200] [Batch 937/938] [D loss: 0.151719] [G loss: 0.327375]
# [Epoch 1/200] [Batch 937/938] [D loss: 0.168202] [G loss: 0.347376]
# [Epoch 2/200] [Batch 937/938] [D loss: 0.227727] [G loss: 0.531862]
# [Epoch 3/200] [Batch 937/938] [D loss: 0.204098] [G loss: 0.325555]
# [Epoch 4/200] [Batch 937/938] [D loss: 0.225541] [G loss: 0.304822]
# [Epoch 5/200] [Batch 937/938] [D loss: 0.235713] [G loss: 0.495769]
# [Epoch 6/200] [Batch 937/938] [D loss: 0.221073] [G loss: 0.279169]
# [Epoch 7/200] [Batch 937/938] [D loss: 0.187322] [G loss: 0.334134]
# [Epoch 8/200] [Batch 937/938] [D loss: 0.251061] [G loss: 0.288760]
# [Epoch 9/200] [Batch 937/938] [D loss: 0.179010] [G loss: 0.282874]
# [Epoch 10/200] [Batch 937/938] [D loss: 0.216306] [G loss: 0.318718]
# ...
